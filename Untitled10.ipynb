# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

# %%
spoty= pd.read_csv("/Users/niyasop/Desktop/ml-packagess/spotify.csv")

# %%
spoty.drop('Unnamed: 0',axis=1,inplace=True)

# %%
spoty.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
spoty.isnull().sum().sum()
# Out:
# 0

# %%
spoty['acousticness'].plot(kind='box');

# %%
spoty.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(spoty['instrumentalness'],orient='h')
# Out:
# /Users/niyasop/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='instrumentalness'>

# %%
numcols = spoty.select_dtypes(include = ['int64','float64'])

# %%
for column in numcols:
    plt.figure()
    numcols.boxplot([column])

# %%
numcols=spoty.columns.
